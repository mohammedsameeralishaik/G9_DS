# %% [markdown]
# ## Insurance_Price_Prediction_By_Linear_Regression , Lasso, Elasticnet,Ridge

# %% [markdown]
# ![title](healthinsurance050623.jpg)

# %%
# importing the lybrarys
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
#importing the data from pdw
data=pd.read_csv('insurance.csv')

# %%
# 5 records of data from start 
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# checking the numbr of rows and columns
data.shape
# Out:
# (1338, 7)

# %%
# columns name in data
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
#checking dtype of the data and any null value
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# describe function 
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
#describe function for object variable
data.describe(include="object")
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %%
#checking the  sum of null value 
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
#now checking the duplicates
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1333    False
# 1334    False
# 1335    False
# 1336    False
# 1337    False
# Length: 1338, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 1

# %%
# now droping the duplicate value
data.drop_duplicates(inplace=True)

# %%
# Now again checking the duplicates
data.duplicated().sum()
# Out:
# 0

# %%
# value count of object columns
for i in data.columns:
    if data[i].dtype=="object":
        print(data[i].value_counts())
# Out:
# sex
# male      675
# female    662
# Name: count, dtype: int64
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64
# region
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: count, dtype: int64

# %%
# labling the data by lablencoder
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()

for i in data.columns:
    if data[i].dtype=="object":
        data[i]=label.fit_transform(data[i])

# %%
data
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1337 rows x 7 columns]

# %%
# visulising the distubetion of the data 
for i in data.columns:
    sns.displot(data[i], color="orange")
    plt.show()

# %%
# painplot of data
sns.pairplot(data=data,hue='smoker')

# %%
# checking the relationship by heat map
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(), annot=True)
# Out:
# <Axes: >

# %%
# checking the outlire in the data
for i in data.columns:
    plt.boxplot(data[i],vert=False)
    plt.xlabel(i)
    plt.show()

# %%
# dealing with outlire  by (IQR METHOD)

q1=np.quantile(data['bmi'],0.25)
q2=np.quantile(data['bmi'],0.50)
q3=np.quantile(data['bmi'],0.75)
q4=np.quantile(data['bmi'],1)

iqr=q3-q1

lower_fence=q1-(1.5*iqr)
upper_fence=q3+(1.5*iqr)
print('lower_fence',lower_fence)
print('upper_fence', upper_fence)
# Out:
# lower_fence 13.674999999999994
# upper_fence 47.31500000000001

# %%
# removing the uotlire
df=data.loc[(data["bmi"]<upper_fence) & (data["bmi"]>lower_fence)]
sns.boxplot(data=df , x="bmi")
# Out:
# <Axes: xlabel='bmi'>

# %%
# sliting the data between x & y
x=data.drop(['charges'], axis=1)
y=data['charges']

# %%
print(x)
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1337 rows x 6 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1337, dtype: float64

# %%
# standerdizing the data 
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
scalar.fit(x)
print(x)
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1337 rows x 6 columns]

# %%
# Importing the train test splite & and spliting the data training the testing
from sklearn.model_selection import train_test_split
x_train ,x_test,y_train,y_test=train_test_split(x,y,train_size=0.2, random_state=2)
x_train.shape,x_test.shape, y_train.shape,y_test.shape
# Out:
# ((267, 6), (1070, 6), (267,), (1070,))

# %% [markdown]
# # Linear regression

# %%
# Import the linearregression and asining 
from sklearn.linear_model import LinearRegression
linear=LinearRegression()

# %%
# fiting the data in  Linearregression=(LR)
linear.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# checking the value of coef and intercept
print('valeu of slope =', linear.coef_)
print('valeu of intercept=', linear.intercept_)
# Out:
# valeu of slope = [  293.50073051  1029.88996728   254.18700051   893.60975149
#  22806.71093328   -35.00136538]
# valeu of intercept= -12362.837267228148

# %%
traning_predict=linear.predict(x_train)

# traning score
from sklearn.metrics import r2_score
train_r2_score=r2_score(y_train, traning_predict)
print('traning_acc_score=' , train_r2_score)
# Out:
# traning_acc_score= 0.7562794246111765

# %%
# hare i am assining predctiin of linear regresion in y_pridect
y_pridect=linear.predict(x_test)

# %%
l_train=linear.score(x_train,y_train)
l_test=linear.score(x_test,y_test)
print(['linear_training_accu',l_train, 'linear_testing_accu', l_test])
# Out:
# ['linear_training_accu', 0.7562794246111765, 'linear_testing_accu', 0.7382803119048738]

# %%
linear.score(x_test,y_test)
# Out:
# 0.7382803119048738

# %% [markdown]
# # Performance metrics

# %%
# Importing the perfoence metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score



mse=mean_squared_error
mae=mean_absolute_error
r2_score=r2_score

# %%
# here the value of perfomence metricd
print('mse=',mse(y_test,y_pridect))
print('mae=',mae(y_test,y_pridect))
print('r2_score=',r2_score(y_test,y_pridect))
print('rmse= ', mse(y_test, y_pridect,squared=False))
# Out:
# mse= 39495985.929931745
# mae= 4330.919334019346
# r2_score= 0.7382803119048738
# rmse=  6284.583194606604

# %%
print('twsting_r2_score')
# Out:
# twsting_r2_score

# %%
# real data vs linear pridection 
sns.scatterplot(y_test, color= "blue")
sns.scatterplot(y_pridect, color= "red")

plt.ylabel('real_data')
# Out:
# Text(0, 0.5, 'real_data')

# %%
real_pridect=y_test-y_pridect

# %%
# 
sns.displot(real_pridect, kind= "kde")

# %% [markdown]
# # Lasso

# %%
# importing lesso regrassion 
from sklearn.linear_model import Lasso
lasso=Lasso()

# %%
# fiting the x, y
lasso.fit(x_train , y_train)
# Out:
# Lasso()

# %%
# coef & intercept of lasso
print('slope_value', lasso.coef_)
print('intersecp', lasso.intercept_)
# Out:
# slope_value [  293.48170298  1026.60156256   254.1719512    892.91631012
#  22800.39285076   -34.14274243]
# intersecp -12359.327446788542

# %%
laso_tra=lasso.score(x_train,y_train)
laso_test=lasso.score(x_test,y_test)
print(['lasso_traing_acc=', laso_tra , 'lasso_testing_acc=', laso_test])
# Out:
# ['lasso_traing_acc=', 0.7562793372470545, 'lasso_testing_acc=', 0.7382826441354537]

# %%
# prection value of 
laso_prdct=lasso.predict(x_test)

# %%
# imporing the perfomence metrics 
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score



mse=mean_squared_error
mae=mean_absolute_error
r2_score=r2_score


print('mse=', mse(y_test,laso_prdct))
print('mae=', mae(y_test,laso_prdct))
print('r2_sore=', r2_score(y_test,laso_prdct))
print('rmse= ', mse(y_test, laso_prdct,squared=False))
# Out:
# mse= 39495633.97419299
# mae= 4331.072480497919
# r2_sore= 0.7382826441354537
# rmse=  6284.555193026233

# %%
# lasso pridection vs real
sns.scatterplot(y_test, color="blue")
sns.scatterplot(laso_prdct, color="red")
# Out:
# <Axes: ylabel='charges'>

# %%
# checking the squnes of the lasso  regrassion 
sns.displot(y_test-laso_prdct , color="blue" , kind="kde")

# %% [markdown]
# # Ridge

# %%
# importin the ridge 
from sklearn.linear_model import Ridge
ridge=Ridge()

# %%
# fiting the data in redge regrasssion
ridge.fit(x_train, y_train)
# Out:
# Ridge()

# %%
# Ridge (coef & intercept)
print('value of slope=', ridge.coef_)
print('value of intercept=', ridge.intercept_)
# Out:
# value of slope= [  292.00297415  1066.30981079   253.96633587   891.43380788
#  22238.59552239   -28.76359611]
# value of intercept= -12219.828591767662

# %%
print('ridge_traning_acc', ridge.score(x_train,y_train), 'ridge_testing_acc' ,ridge.score(x_test,y_test))
# Out:
# ridge_traning_acc 0.7559102761952519 ridge_testing_acc 0.7364342864912607

# %%
# redge predection
r_pri=ridge.predict(x_test)

# %%
#perfomence metrics of ridge reg
print('mse=', mse(y_test,r_pri))
print('mae=', mae(y_test,r_pri))
print('r2_score=', r2_score(y_test,r_pri))
# Out:
# mse= 39774568.692631125
# mae= 4372.658385848585
# r2_score= 0.7364342864912607

# %%
# ridge predction vs real data 
sns.scatterplot(y_test , color="blue")
sns.scatterplot(r_pri , color="red")
# Out:
# <Axes: ylabel='charges'>

# %%
# ridge ditplot real vs pedection
sns.displot(y_test-r_pri , color="blue" , kind="kde")

# %% [markdown]
# # ElasticNet

# %%
# importing Elasticnet 
from sklearn.linear_model import ElasticNet
ela_net=ElasticNet()

# %%
ela_net.fit(x_train, y_train)
# Out:
# ElasticNet()

# %%
print('ElasticNet_coef-', ela_net.coef_)
print('elatocNet_intercept-', ela_net.intercept_)
# Out:
# ElasticNet_coef- [ 245.22354945  879.65640965  262.8974228   674.53727663 5216.01408719
#    99.79285684]
# elatocNet_intercept- -7423.0685951208325

# %%
ela_tra=ela_net.score(x_train,y_train)
ela_test=ela_net.score(x_test,y_test)
print(['elasticnet_traning_acc', ela_tra,'elasticnet_testing_acc' , ela_test])
# Out:
# ['elasticnet_traning_acc', 0.3962019870825354, 'elasticnet_testing_acc', 0.354225288603608]

# %%
ela_pre=ela_net.predict(x_test)

# %%
print('elasticnet_mse-',mse(y_test,ela_pre))
print('elasticnet_mae-',mae(y_test,ela_pre))
print('elasticnet_r_score-',r2_score(y_test,ela_pre))
# Out:
# elasticnet_mse- 97453535.50149137
# elasticnet_mae- 7329.930973013846
# elasticnet_r_score- 0.354225288603608

# %%
print('linear_reg',['linear_training_accu',[l_train], 'linear_testing_accu', [l_test]])
print('lasso',['lasso_traing_acc=', [laso_tra] , 'lasso_testing_acc=', [laso_test]])
print('ridge',['ridge_traning_acc', [ridge.score(x_train,y_train)], 'ridge_testing_acc' ,[ridge.score(x_test,y_test)]])
print('elasticnet',['elasticnet_traning_acc', [ela_tra],'elasticnet_testing_acc' , [ela_test]])
# Out:
# linear_reg ['linear_training_accu', [0.7562794246111765], 'linear_testing_accu', [0.7382803119048738]]
# lasso ['lasso_traing_acc=', [0.7562793372470545], 'lasso_testing_acc=', [0.7382826441354537]]
# ridge ['ridge_traning_acc', [0.7559102761952519], 'ridge_testing_acc', [0.7364342864912607]]
# elasticnet ['elasticnet_traning_acc', [0.3962019870825354], 'elasticnet_testing_acc', [0.354225288603608]]

# %%
from sklearn.model_selection import cross_val_score
crossval_mse=cross_val_score(lasso,x_train,y_train, scoring="neg_mean_squared_error" , cv=10)

# %%
np.mean(crossval_mse)
# Out:
# -33621883.076932706

# %%
cross_r2=crossval_mse=cross_val_score(lasso,x_train,y_train, scoring="r2" , cv=5)
np.mean(cross_r2)
# Out:
# 0.7277434596679729

# %% [markdown]
# ###  Model Predictive System

# %%
inp_data=(32,1,27.75,0,2,0)

inp_data_np_array=np.asarray(inp_data)

reshape_data=inp_data_np_array.reshape(1,-1)

predict=linear.predict(reshape_data)
predict_lasso=lasso.predict(reshape_data)

import math

print('the insurance cost ids =' ,math.trunc (predict[0]))
print('the insurance cost ids =' ,math.trunc (predict_lasso[0]))
# Out:
# the insurance cost ids = 50726
# the insurance cost ids = 50712

# %% [markdown]
# # Final conclusion

# %% [markdown]
# The libraries that ihe used are as follows, numpy , panday , matplotlib , seaborn , math , cross val score and eda visualization
# After checking all the models this are different accuracy of different models
#
#  1.linear_regrasion .
# mse= 39495985.929931745
# mae= 4330.919334019345
# r2_score= 0.7382803119048738
# rmse=  6284.583194606604
#
# 2.lasso
# mse= 39495633.97419299
# mae= 4331.07248049792
# r2_sore= 0.7382826441354537
# rmse=  6284.555193026233
#
# This to are perfoming well in this data / we can go with either of these two models
